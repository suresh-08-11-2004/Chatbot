# %%
def m1(number):
  print("The function is about to begin")
  print("The desired result is {2*number+5}")
  return 2*number+5

# %%
 m1(10)
# Out:
# The function is about to begin
# The desired result is {2*number+5}
# 25

# %%
text = 'hello this is abc from xyz location'

# %%
text.upper()
# Out:
# 'HELLO THIS IS ABC FROM XYZ LOCATION'

# %%
text.lower()
# Out:
# 'hello this is abc from xyz location'

# %%
text.title()
# Out:
# 'Hello This Is Abc From Xyz Location'

# %%
class Student:
  name = 'ABC'
  age = 21
  Class = 'BCom'

# %%
Student
# Out:
# __main__.Student

# %%
Student.name
# Out:
# 'ABC'

# %%
# How to use packages / Libraries

import random

# Empty list
numbers = []

# insert 10,00 numbers into 'numbers'
for _ in range(1000):
    numbers.append(random.randint(0,1000))

# %%
numbers
# Out:
# [875,
#  890,
#  579,
#  544,
#  990,
#  287,
#  775,
#  834,
#  960,
#  231,
#  131,
#  163,
#  566,
#  632,
#  161,
#  902,
#  652,
#  9,
#  436,
#  59,
#  557,
#  520,
#  67,
#  3,
#  592,
#  133,
#  965,
#  539,
#  14,
#  442,
#  989,
#  661,
#  245,
#  447,
#  517,
#  387,
#  129,
#  350,
#  459,
#  39,
#  593,
#  792,
#  986,
#  696,
#  340,
#  200,
#  417,
#  635,
#  854,
#  514,
#  76,
#  833,
#  962,
#  453,
#  307,
#  310,
#  153,
#  461,
#  804,
#  134,
#  872,
#  254,
#  64,
#  271,
#  245,
#  875,
#  928,
#  410,
#  376,
#  136,
#  652,
#  151,
#  425,
#  105,
#  887,
#  169,
#  385,
#  841,
#  287,
#  975,
#  81,
#  52,
#  618,
#  336,
#  684,
#  134,
#  625,
#  317,
#  885,
#  165,
#  451,
#  205,
#  732,
#  457,
#  653,
#  103,
#  320,
#  547,
#  319,
#  791,
#  688,
#  463,
#  769,
#  766,
#  922,
#  402,
#  198,
#  224,
#  873,
#  236,
#  68,
#  420,
#  934,
#  30,
#  153,
#  328,
#  81,
#  135,
#  133,
#  344,
#  204,
#  810,
#  888,
#  486,
#  406,
#  695,
#  81,
# ...

# %%
URL endpoint:https://jsonplaceholder.typicode.com/posts

# %%
import requests

# %%
# Get the data from the endpoint URL
response=requests.get("https://jsonplaceholder.typicode.com/posts")

# %%
response.json()
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
# ...

# %%
#creating a function to get the data from Endpoint

import requests

def getData(Endpoint):
 response = requests.get(Endpoint)
 return response.json()

# %%
getData("https://jsonplaceholder.typicode.com/posts")
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
# ...

# %%
import requests

# %%
url="https://jsonplaceholder.typicode.com/post"

# %%
 response=requests.get(url=url)

# %%
# To find out the response's status code
response.status_code
# Out:
# 404

# %%
# conditional statements

if response.status_code == 200:
    print(response.json())
else:
 print ("failure")
# Out:
# failure

# %%
from google import genai
client=genai.Client(api_key="AIzaSyABADVXn25w_NkSkRbTGuUXw6Ec1l1QBnc")

#send requests to Gemini
response = client.models.generate_content(
    model='gemini-2.0-flash-exp',
    contents='Tell me about face book')
#print(response.text)
#clearthe cache and make a final to ask any question
import sys, time
for _ in response.text:
  sys.stdout.write(_)
  sys.stdout.flush()
  time.sleep(0.02)
# Out:
# Okay, let's dive into Facebook. It's a massive and complex platform, so I'll try to give you a comprehensive overview.
#
# **What is Facebook?**
#
# *   **Social Networking Giant:** At its core, Facebook is a social networking service. It allows users to connect with friends, family, colleagues, and other people who share common interests.
# *   **Owned by Meta:** Facebook is the flagship product of Meta Platforms, Inc. (formerly Facebook, Inc.), which also owns Instagram, WhatsApp, and other companies.
# *   **Global Reach:** It's one of the most widely used social media platforms in the world, with billions of active users.
#
# **Key Features and Functionality:**
#
# *   **Profiles:** Users create personal profiles that include information about themselves, such as their name, age, location, education, work experience, and interests.
# ...
